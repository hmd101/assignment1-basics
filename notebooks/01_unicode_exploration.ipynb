# %%
assert chr(ord('a')) == 'a'

# %%
assert ord(chr(0)) == 0
chr(0)
# Out:
# '\x00'

# %%
# Out:
# '\x00'

# %%
test_string ="hello! こんにちは!"
utf8_encoded = test_string.encode("utf-8")
print(utf8_encoded)
# Out:
# b'hello! \xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'
# <class 'bytes'>

# %%
print(type(utf8_encoded))
print(len(test_string))
list(utf8_encoded)
# Out:
# <class 'bytes'>
# 13
# [104,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  227,
#  129,
#  147,
#  227,
#  130,
#  147,
#  227,
#  129,
#  171,
#  227,
#  129,
#  161,
#  227,
#  129,
#  175,
#  33]

# %%
assert utf8_encoded.decode("utf-8") == test_string

print(utf8_encoded.decode("utf-8"))
# Out:
# hello! こんにちは!
